# %%
import pandas as pd
df=pd.read_csv("/home/msois/Downloads/Accidents/Accident_Cities.csv")
df.head()
# Out:
#        Name of City  Total number of Fatal Accidents - 2011  \
# 0              Agra                                   336.0
# 1         Ahmedabad                                   222.0
# 2  Asansol-Durgapur                                   229.0
# 3        Aurangabad                                   161.0
# 4         Bengaluru                                   689.0
#
#    All Accidents - 2011  Persons Killed - 2011  Persons Injured - 2011  \
# 0                1299.0                  632.0                  1046.0
# 1                2020.0                  227.0                  2036.0
# 2                 368.0                  230.0                   185.0
# 3                 719.0                  173.0                   744.0
# 4                6031.0                  720.0                  4952.0
#
#    Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 0                                   381.0                 922.0
# ...

# %%
# List 3 Cities where maximum number of people injured from 2011 to 2015.
df.sort_values(['Persons Injured - 2011','Persons Injured - 2012','Injured - 2014','Injured - 2015'],ascending=False).head(3)
# Out:
#    Name of City  Total number of Fatal Accidents - 2011  All Accidents - 2011  \
# 7         Delhi                                  2007.0                7281.0
# 27       Mumbai                                   539.0               25471.0
# 4     Bengaluru                                   689.0                6031.0
#
#     Persons Killed - 2011  Persons Injured - 2011  \
# 7                  2065.0                  7226.0
# 27                  563.0                  5059.0
# 4                   720.0                  4952.0
#
#     Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 7                                   1822.0                6937.0
# 27                                   471.0               24592.0
# 4                                    707.0                5508.0
#
#     Persons Killed - 2012  Persons Injured - 2012  Fatal Accidents - 2013  \
# 7                  1866.0                  6633.0                  1778.0
# ...

# %%
# Is there any City/es whose injury count decreased from 2009 to 2012 (In each year)? If so list cities
df.sort_values(['Persons Injured - 2011','Persons Injured - 2012'],ascending=True).head(3)
# Out:
#         Name of City  Total number of Fatal Accidents - 2011  \
# 37          Varanasi                                    73.0
# 8            Dhanbad                                    74.0
# 2   Asansol-Durgapur                                   229.0
#
#     All Accidents - 2011  Persons Killed - 2011  Persons Injured - 2011  \
# 37                 142.0                   73.0                    69.0
# 8                  138.0                   82.0                   106.0
# 2                  368.0                  230.0                   185.0
#
#     Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 37                                   216.0                 379.0
# 8                                     49.0                 144.0
# 2                                    199.0                 380.0
#
#     Persons Killed - 2012  Persons Injured - 2012  Fatal Accidents - 2013  \
# 37                  216.0                   160.0                   217.0
# ...

# %%
import pandas as pd
df1=pd.read_csv("/home/msois/Downloads/Accidents/Accident_States.csv")
df1.head()
# Out:
#           Unnamed: 0                                         Unnamed: 1  \
# 0         States/UTs  State/UT-Wise Total Number of Persons Injured ...
# 1     Andhra Pradesh                                              52157
# 2  Arunachal Pradesh                                                530
# 3              Assam                                               5522
# 4              Bihar                                               7113
#
#                                           Unnamed: 2  \
# 0  State/UT-Wise Total Number of Persons Injured ...
# 1                                              53928
# 2                                                491
# 3                                               7579
# 4                                               8106
#
#                                           Unnamed: 3  \
# 0  State/UT-Wise Total Number of Persons Injured ...
# 1                                              55583
# ...

# %%
#List 5 major states which has more deaths due to over speed from 2010 to 2015. Show plot also.

df.sort_values(['KIlled due to Over Speed'],ascending=False).head(5)
# Out:
#         Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 15     Maharashtra      47878      46985      45628      43847
# 1   Andhra Pradesh      52157      53928      55583      51552
# 24      Tamil Nadu      70504      75445      74245      78348
# 12       Karnataka      61697      61774      59591      58659
# 22       Rajasthan      32317      31033      28666      28135
#
#     KIlled due to Over Speed  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 15                    8704.0      4404.0      7301.0      8549.0      8607.0
# 1                     7471.0      6407.0      5211.0      4560.0      6201.0
# 24                    5703.0      5695.0      6323.0      6412.0      8043.0
# 12                    5678.0      4501.0      6657.0      5205.0      4304.0
# 22                    4736.0      4681.0      4451.0      4650.0      4621.0
#
#        ...       Unnamed: 13  Accidents due to Alcohal and drugs  Unnamed: 15  \
# ...

# %%
import pandas as pd
df1=pd.read_csv("/home/msois/Downloads/Accidents/Accident_States.csv")
# Write a method to compute the average deaths for any given state from year 2012 to 2016 due to over speed.
df1['KIlled due to Over Speed'].mean()
# Out:
# 1701.5

# %%
# List 5 major cities which has maximum deaths from 2011 to 2015. Plot graph also.
import pandas as pd
df=pd.read_csv("/home/msois/Downloads/Accidents/Accident_Cities.csv")
import matplotlib.pyplot as plt
df.sort_values(['Persons Killed - 2012', 'Killed - 2015'],ascending=False).head(5).copy()
# Out:
#    Name of City  Total number of Fatal Accidents - 2011  All Accidents - 2011  \
# 7         Delhi                                  2007.0                7281.0
# 42      Chennai                                     NaN                   NaN
# 4     Bengaluru                                   689.0                6031.0
# 43       Kanpur                                     NaN                   NaN
# 30        Patna                                   507.0                1225.0
#
#     Persons Killed - 2011  Persons Injured - 2011  \
# 7                  2065.0                  7226.0
# 42                    NaN                     NaN
# 4                   720.0                  4952.0
# 43                    NaN                     NaN
# 30                  507.0                   576.0
#
#     Total number of Fatal Accidents - 2012  All Accidents - 2012  \
# 7                                   1822.0                6937.0
# ...

# %%
import matplotlib.pyplot as plt

df.plot.scatter(x='Persons Killed - 2011',y='Killed - 2015',color='red').axis=0
plt.show()

# %%
# Show the deaths due accidents from 2011 to 2015 for the cities Delhi, Bengaluru, Mumbai, Kolkata, Lucknow.
df[df['Persons Killed - 2011']==df['Persons Killed - 2011'['Delhi,Bengaluru','Mumbai', 'Kolkata', 'Lucknow']]
# Out:
# /home/msois/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:798: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(x, name)(y)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-7f1c5de06674> in <module>()
#       1 # Show the deaths due accidents from 2011 to 2015 for the cities Delhi, Bengaluru, Mumbai, Kolkata, Lucknow.
# ----> 2 df[df['Persons Killed - 2011']==['Delhi,Bengaluru','Mumbai', 'Kolkata', 'Lucknow']]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#     859
#     860             with np.errstate(all='ignore'):
# --> 861                 res = na_op(values, other)
#     862             if is_scalar(res):
#     863                 raise TypeError('Could not compare %s type with Series' %
#
# ...

# %%
# Show the deaths due accidents from 2011 to 2015 for the cities Delhi, Bengaluru, Mumbai, Kolkata, Lucknow.
import pandas as pd
import random
df=pd.read_csv("/home/msois/Downloads/Accidents/Accident_Cities.csv")
df.loc['Ahmedabad']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [Ahmedabad] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-131-a3f540a4e12b> in <module>()
#       3 import random
# ...

# %%
# List any cites whose total accidents decreased in each year.
df.sort_values([All Accidents - 2011],ascending=True).head(3)
# Out:
#   File "<ipython-input-135-25f90cca8eb0>", line 2
#     df.sort_values([All Accidents - 2011],ascending=True).head(3)
#                                 ^
# SyntaxError: invalid syntax
